# %%
### This file does a RZ gate (1 parameter, 1 qubit) with X,Y control
using QuantumCollocation
using NamedTrajectories
using TrajectoryIndexingUtils

# %%
const Units = 1e9
const MHz = 1e6 / Units
const GHz = 1e9 / Units
const ns = 1e-9 * Units
const μs = 1e-6 * Units
;

# %%
# Operators
const Paulis = Dict(
    "I" => Matrix{ComplexF64}([1 0; 0 1]),
    "X" => Matrix{ComplexF64}([0 1; 1 0]),
    "Y" => Matrix{ComplexF64}([0 im; -im 0]),
    "Z" => Matrix{ComplexF64}([1 0; 0 -1]),
)
const a = [0 1; 0 0]
const ad = transpose(a);
excitation(theta,phi) = 1/sqrt(2) * [1 -exp(im*phi) ; exp(im*theta) exp(im*(theta+phi)) ] 


H_drives = [
     Paulis["X"],
     Paulis["Y"]
]
system = QuantumSystem(H_drives);
t_f = 10 * ns
n_steps = 51
times = range(0, t_f, n_steps)  # Alternative: collect(0:Δt:t_f)
Δt = times[2] - times[1]
n_controls=2
n_qubits=1;

# %%
### Generate Initial Trajectories 
PICO_max_iter = 100

# Shape the cost function with weights on states and controls
Q = 1000.
R =1e-2
R_b=200.0
# Add control bounds
a_bound = 1.0
dda_bound = 1.0

ops = Options()
ops.print_info_string = "yes"
ops.recalc_y = "yes"
ops.recalc_y_feas_tol = 1.0 ##down
ops.print_level = 0
p=UnitarySmoothPulseProblem(
                system,
                excitation(pi,pi),
                n_steps,
                Δt;
                a_bound=a_bound,
                dda_bound=dda_bound,
                Q=Q,
                R=R,
                verbose=true,
                hessian_approximation=true,
                pade_order=10,
                free_time=true,
                timesteps_all_equal=true,
                max_iter=PICO_max_iter,
                ipopt_options=ops,
                )
min_time_problem  = UnitaryMinimumTimeProblem(p; final_fidelity=1-1e-5,max_iter=500);
solve!(min_time_problem)
# Out:
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# applying constraint: bounds on Δt
# applying constraint: time step all equal constraint
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# applying constraint: bounds on Δt
# applying constraint: time step all equal constraint
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.14, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:     4456
# Number of nonzeros in inequality constraint Jacobian.:        8
# Number of nonzeros in Lagrangian Hessian.............:    24067
#
# Total number of variables............................:      753
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      251
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      650
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        1
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0206629e+01 1.85e+00 6.79e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.1915969e+01 4.74e-02 2.07e+02  -1.0 9.91e-01   2.0 1.12e-02 1.00e+00h  1
#    2  8.5904775e+00 9.39e-03 5.40e+01  -1.0 1.01e-01   2.4 1.00e+00 7.99e-01f  1
#    3  8.1835746e+00 8.90e-03 2.63e+02  -1.0 1.90e-02   1.9 1.00e+00 5.30e-02h  1
#    4  9.4077291e+00 6.37e-04 2.01e+02  -1.0 4.64e-02   1.5 6.19e-01 1.00e+00f  1
#    5  9.1592097e+00 5.36e-04 4.04e+02  -1.0 2.49e-02   1.0 1.00e+00 1.59e-01h  1
#    6  9.9336725e+00 1.15e-03 2.13e+02  -1.0 7.10e-01   0.5 4.55e-01 8.14e-02f  4
#    7  1.0280664e+01 1.89e-04 8.12e-01  -1.0 3.36e-02   0.9 1.00e+00 1.00e+00f  1
#    8  9.1122007e+00 8.35e-05 4.93e-02  -1.7 1.14e-02   0.5 1.00e+00 1.00e+00f  1
#    9  7.2809683e+00 1.30e-03 2.96e+00  -2.5 3.89e-02  -0.0 9.19e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.
# Total seconds in IPOPT                               = 124.478
#
# EXIT: Optimal Solution Found.

# %%
Δt = ceil(1.2 * min_time_problem.trajectory[:Δt][1]*100)/100
# Out:
# 0.13

# %%
N = 11
trajectory_list,glued_trajectory_list = Interpolator2D(
    excitation,
    system,
    n_steps,
    N,
    Δt;
    Q=Q,
    R=R,
    R_b=R_b,
    a_bound=a_bound,
    dda_bound=dda_bound,
    ipopt_options=ops,
    max_iter=PICO_max_iter,
    fidelity_constraint = 1e-5
);
# Out:
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 0.0)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 0.6283185307179586)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 1.2566370614359172)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 1.8849555921538759)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 2.5132741228718345)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 3.141592653589793)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 3.7699111843077517)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 4.39822971502571)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 5.026548245743669)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.0, 5.654866776461628)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.6283185307179586, 0.0)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.6283185307179586, 0.6283185307179586)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.6283185307179586, 1.2566370614359172)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (0.6283185307179586, 1.8849555921538759)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# ...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (1.8849555921538759, 1.2566370614359172)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (1.8849555921538759, 1.8849555921538759)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (1.8849555921538759, 2.5132741228718345)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (1.8849555921538759, 3.141592653589793)-----------------------
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗1
# applying constraint: initial value of a1
# applying constraint: initial value of Ũ⃗2
# applying constraint: initial value of a2
# applying constraint: initial value of Ũ⃗3
# applying constraint: initial value of a3
# applying constraint: initial value of Ũ⃗4
# applying constraint: initial value of a4
# applying constraint: final value of a1
# applying constraint: final value of a2
# applying constraint: final value of a3
# applying constraint: final value of a4
# applying constraint: bounds on a1
# applying constraint: bounds on dda1
# applying constraint: bounds on a2
# applying constraint: bounds on dda2
# applying constraint: bounds on a3
# applying constraint: bounds on dda3
# applying constraint: bounds on a4
# applying constraint: bounds on dda4
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
#     building dynamics from integrators...
#         constructing knot point dynamics functions...
#         determining dynamics derivative structure...
#             computing jacobian sparsity...
#             creating full trajectory jacobian structure...
#         constructing full dynamics derivative functions...
#     building evaluator...
#     initializing optimizer...
# applying constraint: initial value of Ũ⃗
# applying constraint: initial value of a
# applying constraint: final value of a
# applying constraint: bounds on a
# applying constraint: bounds on dda
# -----------------------Initial Angle (1.8849555921538759, 3.7699111843077517)-----------------------

# %%
DATA = sample2D(trajectory_list,Δt,n_qubits,system,50,N,excitation)
findmax(DATA)

# %%
using Plots
gr()
Plots.heatmap(range(0,2*pi,50),
    range(0,2*pi,50), log10.(DATA),
    xlabel="θ values", ylabel="ϕ values",
    title="Log Infidelity")

# %%
DATA = simple_sample2D(glued_trajectory_list,Δt,n_qubits,system,50,N,excitation)
findmax(DATA)

# %%
gr()
Plots.heatmap(range(0,2*pi,50),
    range(0,2*pi,50), log10.(DATA),
    xlabel="θ values", ylabel="ϕ values",
    title="Log Infidelity")

# %%
data,d_data,dd_data = parse2D(trajectory_list,2,N);

# %%
verify2D(dd_data,n_qubits,system,Δt,n_steps,N,excitation)

# %%
verify2D([[glued_trajectory_list[i][j][:dda] for j in 1:N] for i in 1:N],n_qubits,system,Δt,n_steps,N,excitation)

# %%
export_csv2D([[glued_trajectory_list[i][j][:dda] for j in 1:N] for i in 1:N],n_controls,N,"XYControlU2_accels.csv")
